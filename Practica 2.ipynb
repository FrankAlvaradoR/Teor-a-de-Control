# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankAlvaradoR/Teor-a-de-Control/blob/main/Practica%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control

# %%
from control.matlab import *
import matplotlib.pyplot as plt
#Modelo como función de transferencia
num = [193.3]
den = [1.0, 18.735, 0.0]
sys = tf(num,den) #Lazo abierto
print(sys)

#Modelo en lazo cerrado
sys_cl = feedback(sys,1)

#Respuesta al escalón
t,y = ctrl.step_response(sys_cl)

#Graficas
plt.plot(t,y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
#     193.3
# -------------
# s^2 + 18.73 s
# Text(0.5, 0, 'segundos')

# %%
plt.figure(2)
ctrl.bode_plot(sys)

plt.figure(3)
polos,zeros = pzmap(sys_cl), plt.grid(True)
print(polos[0])
print(polos[1])

print(zero(sys))
print(pole(sys))
print(dcgain(sys))
# Out:
# [-9.3675+10.27375023j -9.3675-10.27375023j]
# []
# []
# [-18.735+0.j   0.   +0.j]
# inf

# %%
raices  = rlocus(sys)

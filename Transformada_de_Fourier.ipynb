# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankAlvaradoR/Teor-a-de-Control/blob/main/Transformada_de_Fourier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt

#Etiquetamos la grafica 
fig, ax = plt.subplots()
ax.set_title('Señal')
ax.set_ylabel("Amplitud")
ax.set_xlabel("Tiempo en seg")
#definimos la señal
t = np.arange(0, 3, .001)
F=1;
pi = np.pi;
w = 2*pi*F;
y = np.sin(w*t)
#Graficamos 
plt.plot(t, y)
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(0, 3)
plt.ylim(-2, 2)
plt.show()

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath

#Etiquetamos la grafica 
fig, ax = plt.subplots()
ax.set_title('Señal')
ax.set_ylabel("Amplitud")
ax.set_xlabel("Tiempo en seg")
#definimos la señal
t = np.arange(0, 3, .001)
F=1;
pi = np.pi;
w = 2*pi*F;

y = 1+np.sin(w*t)+2*np.cos(w*t)+np.cos(2*w*t+(pi/4)) 
#Graficamos 
plt.plot(t, y)
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(0, 3)
plt.ylim(-4, 4)
plt.show()

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath

#Etiquetamos la grafica 
fig, ax = plt.subplots()
ax.set_title('Señal')
ax.set_ylabel("Amplitud")
ax.set_xlabel("Tiempo en seg")
#definimos la señal
t = np.arange(0, 3, .01)
F=1;
pi = np.pi;
w = 2*pi*F;

y = 1+np.sin(w*t)+2*np.cos(w*t)+np.cos(2*w*t+(pi/4)) 
TF=np.fft.fft(y)

#Graficamos 
plt.stem(abs(TF))
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath

#Etiquetamos la grafica 
fig, ax = plt.subplots()
ax.set_title('Señal')
ax.set_ylabel("Amplitud")
ax.set_xlabel("Tiempo en seg")
#definimos la señal
t = np.arange(0, 3, .01)
F=1;
pi = np.pi;
w = 2*pi*F;

y = 1+np.sin(w*t)+2*np.cos(w*t)+np.cos(2*w*t+(pi/4)) 
TF=np.fft.fft(y)

#Graficamos 

plt.stem(abs(TF))
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(-10, 10)
plt.show()

plt.stem(abs(TF))
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(290, 310)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath

#Etiquetamos la grafica 
fig, ax = plt.subplots()
ax.set_title('Señal')
ax.set_ylabel("Amplitud")
ax.set_xlabel("Tiempo en seg")
#definimos la señal
fm=200
t = np.arange(0, 3, 1/fm)
F=1;
pi = np.pi;
w = 2*pi*F;

y = 1+np.sin(w*t)+2*np.cos(w*t)+np.cos(2*w*t+(pi/4)) 
TF=np.fft.fft(y)


N=len(y);
vecf=fm*( np.arange(0,(N/2)) )/N;

N=len(y)
vecf=fm*(np.arange(0, (N/2)+1/fm, 1))/N
F=np.fft.fft(y)
F2=F[0:int(N/2+1)]
psdx=(1/N)*abs(F2)
psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]

#Graficamos 
plt.stem(vecf,psdx)
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(-1, 10)
plt.show()

plt.plot(t, y)
plt.axhline(0, color="r")
#plt.axvline(0.1, color="g")
plt.xlim(0, 3)
plt.ylim(-4, 4)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath
#Simulación de señal continua
fs=1000;
F=.5;
ts = np.arange(0, 1, 1/fs)
pi = np.pi;
w = 2*pi*F;
y = np.sin(w*ts)
plt.plot(ts, y)

#definimos la señal iscreta
fm=8
t = np.arange(0, 1, 1/fm)
y = np.sin(w*t)
plt.stem(t,y,'r')
plt.show()
print(y)
print("\n")

#Transformada de Fourier. 
N=len(y);
vecf=fm*( np.arange(0,(N/2)+1) )/N;
TF=np.fft.fft(y)
F=np.fft.fft(y)
F2=F[0:int(N/2+1)]
psdx=(1/N)*abs(F2)
psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]

print(vecf)
print(psdx)
#Graficamos 
plt.stem(vecf,psdx)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# [0.         0.38268343 0.70710678 0.92387953 1.         0.92387953
#  0.70710678 0.38268343]
#
#
# [0. 1. 2. 3. 4.]
# [0.62841744 0.44134172 0.10355339 0.05865828 0.02486405]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Cargamos las librerias
import numpy as np
import matplotlib.pyplot as plt
import cmath
fig, ax = plt.subplots(2, 1, sharey = True)




#Simulación de señal continua
fs=100;
ts = np.arange(0,2, 1/fs)
pi = np.pi;

y1 = 5*np.sin(2*pi*5*ts)
y2 = 3*np.sin(2*pi*15*ts)
y3 = 2*np.sin(2*pi*20*ts)
y4 = 1*np.sin(2*pi*1*ts)
y5 = 2*np.sin(2*pi*7*ts)
y=y1+y2+y3+y4+y5;
ax[0].plot(ts, y)

#Transformada de Fourier. 
N=len(y);
vecf=fs*( np.arange(0,(N/2)+1) )/N;
TF=np.fft.fft(y)
F=np.fft.fft(y)
F2=F[0:int(N/2+1)]
psdx=(1/N)*abs(F2)
psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]

#Graficamos 
ax[1].plot(vecf,psdx)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
directorio = "/content/drive/MyDrive/Colab_Notebooks/Procesamiento_Imagenes/"

from scipy.io import wavfile
import scipy.io
# Out:
# Mounted at /content/drive

# %%
# !pip install pydub
from pydub import AudioSegment
sound = AudioSegment.from_mp3(directorio+"audio1.mp3")
sound.export(directorio+"audio1.wav", format="wav")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# <_io.BufferedRandom name='/content/drive/MyDrive/Colab_Notebooks/Procesamiento_Imagenes/audio1.wav'>

# %%
fm, source = wavfile.read(directorio+"audio1.wav")
print(fm)
t=np.arange(0,len(source)/fm, 1/fm)
plt.plot(t,source)
# Out:
# 48000
# ...

# %%
#Transformada de Fourier. 
fs=fm;
N=len(source);
if N % 2 == 0:
  vecf=fs*( np.arange(0,(N/2)+1) )/N;
else:
  vecf=fs*( np.arange(0,(N/2)) )/N;
  
F=np.fft.fft(source[:,0])
F2=F[0:int(N/2+1)]
psdx=(1/N)*abs(F2)
psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]

#Graficamos 
plt.plot(vecf,psdx)
plt.show()

# %%
#Transformada de Fourier. 
fs=fm;
N=len(source);
if N % 2 == 0:
  vecf=fs*( np.arange(0,(N/2)+1) )/N;
else:
  vecf=fs*( np.arange(0,(N/2)) )/N;
F=np.fft.fft(source[:,0])
F2=F[0:int(N/2+1)]
psdx=(1/N)*abs(F2)
psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]

#Graficamos 
plt.plot(vecf,psdx)
plt.xlim(400, 500)
plt.ylim(0, 60)
plt.show()

# %%
#Transformada de Fourier. 
#Graficamos la señal de audio. 
y=source[:,0];
plt.plot(y)
plt.show()
fs=fm;

#Transformada corta.
ventana = 1
t1=np.arange(0,ventana,1/fs);
v_ven = np.arange(0,np.floor(len(t)/len(t1)) )
del PSDX
longitud = len(t1)
if longitud % 2 == 0:
  PSDX = np.empty((len(v_ven), int(longitud/2+1)), int)
else:
  PSDX = np.empty((len(v_ven), int(longitud/2)), int)
print(np.shape(PSDX))
for m in v_ven:
  inicia=(m*fs*ventana)
  termina=(m+1)*fs*ventana;
  V=y[int(inicia):int(termina)]
  
  F=np.fft.fft(V)
  F2=F[0:int(N/2+1)]
  psdx=(1/N)*abs(F2)
  psdx[1:len(psdx)-1]=2*psdx[1:len(psdx)-1]
  for m in np.range()
    PSDX = np.append(PSDX, np.array([psdx]), axis=0)
  print("ventana procesada {}",m)

N=len(V);
if N % 2 == 0:
  vecf=fs*( np.arange(0,(N/2)+1) )/N;
else:
  vecf=fs*( np.arange(0,(N/2)) )/N;


#Graficamos 
plt.plot(vecf,psdx)
plt.show()
# Out:
# (244, 24001)
# ventana procesada {} 0.0
# ventana procesada {} 1.0
# ventana procesada {} 2.0
# ventana procesada {} 3.0
# ventana procesada {} 4.0
# ventana procesada {} 5.0
# ventana procesada {} 6.0
# ventana procesada {} 7.0
# ventana procesada {} 8.0
# ventana procesada {} 9.0
# ventana procesada {} 10.0
# ventana procesada {} 11.0
# ventana procesada {} 12.0
# ventana procesada {} 13.0
# ventana procesada {} 14.0
# ventana procesada {} 15.0
# ventana procesada {} 16.0
# ventana procesada {} 17.0
# ventana procesada {} 18.0
# ventana procesada {} 19.0
# ventana procesada {} 20.0
# ventana procesada {} 21.0
# ventana procesada {} 22.0
# ventana procesada {} 23.0
# ventana procesada {} 24.0
# ventana procesada {} 25.0
# ventana procesada {} 26.0
# ventana procesada {} 27.0
# ventana procesada {} 28.0
# ventana procesada {} 29.0
# ventana procesada {} 30.0
# ventana procesada {} 31.0
# ventana procesada {} 32.0
# ventana procesada {} 33.0
# ventana procesada {} 34.0
# ...

# %%
plt.figure(figsize=(5,50))
pixel_plot = plt.imshow(np.transpose(np.log(PSDX)), cmap='jet')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
PSDX = np.empty((len(v_ven), int(longitud/2+1)), int)
print(np.shape(PSDX))
print((len(v_ven)))
print(longitud)
# Out:
# (244, 24000)
# 244
# 47999

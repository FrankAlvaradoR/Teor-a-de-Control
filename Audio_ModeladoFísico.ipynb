# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankAlvaradoR/Teor-a-de-Control/blob/main/Audio_ModeladoF%C3%ADsico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Audio, display
import numpy as np

fs = 44000
F=220;
t = np.linspace(0,5,fs*5)
data=np.exp(-2*t)*(10*np.sin(2*np.pi*F*t)+7*np.cos(2*np.pi*F*2*t)+2*np.sin(2*np.pi*F*3*t))
plt.plot(t,data)
Audio(data,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
